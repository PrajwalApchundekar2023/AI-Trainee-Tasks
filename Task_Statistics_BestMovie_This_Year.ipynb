# %% [markdown]
# <a href="https://colab.research.google.com/github/PrajwalApchundekar2023/AI-Trainee-Tasks/blob/main/Task_Statistics_BestMovie_This_Year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import pandas as pd;
import seaborn as sns;

# %%
# importing CSV file
w=pd.read_csv("/content/BestMovie-by-Year-Netflix.csv")
w.head(5)
# Out:
#    index                 TITLE  RELEASE_YEAR  SCORE MAIN_GENRE MAIN_PRODUCTION
# 0      0       White Christmas          1954    7.5    romance              US
# 1      1  The Guns of Navarone          1961    7.5        war              US
# 2      2          My Fair Lady          1964    7.8      drama              US
# 3      3      Bonnie and Clyde          1967    7.7      drama              US
# 4      4           Dirty Harry          1971    7.7   thriller              US

# %%
w.tail()
# Out:
#     index                                     TITLE  RELEASE_YEAR  SCORE  \
# 44     44                                 Andhadhun          2018    8.2
# 45     45           Dave Chappelle: Sticks & Stones          2019    8.4
# 46     46  David Attenborough: A Life on Our Planet          2020    9.0
# 47     47                        Bo Burnham: Inside          2021    8.7
# 48     48                       The Tinder Swindler          2022    7.2
#
#      MAIN_GENRE MAIN_PRODUCTION
# 44     thriller              IN
# 45       comedy              US
# 46  documentary              GB
# 47       comedy              US
# 48        crime              GB

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            49 non-null     int64
#  1   TITLE            49 non-null     object
#  2   RELEASE_YEAR     49 non-null     int64
#  3   SCORE            49 non-null     float64
#  4   MAIN_GENRE       49 non-null     object
#  5   MAIN_PRODUCTION  49 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.4+ KB

# %%
x=w

# %%
sns.displot(x['MAIN_PRODUCTION'])

# %%
sns.displot(x['SCORE'])

# %%
sns.displot(x['RELEASE_YEAR'])

# %%
sns.displot(x['MAIN_GENRE'])

# %%
sns.barplot(x['RELEASE_YEAR'])
# Out:
# <Axes: ylabel='RELEASE_YEAR'>

# %%
sns.barplot(x['SCORE'])
# Out:
# <Axes: ylabel='SCORE'>

# %%
y=w.head(10)

# %%
sns.barplot(y['RELEASE_YEAR'])
# Out:
# <Axes: ylabel='RELEASE_YEAR'>

# %%
sns.barplot(x['MAIN_PRODUCTION'])
# Out:
# <Axes: ylabel='MAIN_PRODUCTION'>

# %%
sns.barplot(x['MAIN_GENRE'])
# Out:
# <Axes: ylabel='MAIN_GENRE'>

# %%
sns.jointplot(x['RELEASE_YEAR'])

# %%
sns.jointplot(x['MAIN_PRODUCTION'])

# %%
sns.jointplot(x['MAIN_GENRE'])

# %%
sns.jointplot(x['SCORE'])

# %%
sns.jointplot(x['SCORE'],kind="hex")
#scatter, reg, hex, hist

# %%
sns.jointplot(x['SCORE'],kind="reg")
#scatter, reg, hex, hist

# %%
sns.jointplot(x['SCORE'],kind="hist")
#scatter, reg, hex, hist

# %%
sns.pairplot(x[['TITLE','SCORE','RELEASE_YEAR']])

# %%
sns.barplot(x[['MAIN_GENRE','SCORE']])
# Out:
# <Axes: >

# %%
sns.stripplot(x[['RELEASE_YEAR','SCORE']])
# Out:
# <Axes: >

# %%
sns.boxplot(x[['SCORE','RELEASE_YEAR']])
# Out:
# <Axes: >

# %%
sns.countplot(x[['TITLE','RELEASE_YEAR','SCORE']])
# Out:
# <Axes: ylabel='count'>

# %%
sns.pointplot(x[['TITLE','RELEASE_YEAR','SCORE']])
# Out:
# <Axes: >

# %%
sns.lmplot(x='RELEASE_YEAR',y="SCORE",data=x)
