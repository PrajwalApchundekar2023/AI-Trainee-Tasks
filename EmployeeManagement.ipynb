# %% [markdown]
# <a href="https://colab.research.google.com/github/PrajwalApchundekar2023/AI-Trainee-Tasks/blob/main/EmployeeManagement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistics
#
# 1.   Pandas
# 2.   Seaborn

# %%
# importing libraries
import pandas as pd;
import seaborn as sns;
sns=(color_codes=True);

# %%
# importing CSV file
w=pd.read_csv("/Employee.csv")
w.head(5)
# Out:
#    sno     name  age gender department
# 0    1  sathish   20      M         AI
# 1    2  deepthi   20      F         DA
# 2    3   yamuna   20      F         DA
# 3    4     joey   20      M         AI
# 4    5      ram   20      M         AI

# %%
w.tail()
# Out:
#     sno    name  age gender department
# 10   11  sanjay   20      M         DA
# 11   12    jana   20      M         DA
# 12   13    yuga   20      M         DA
# 13   14    hari   20      M         DA
# 14   15  sudhan   20      M         DA

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sno         15 non-null     int64
#  1   name        15 non-null     object
#  2   age         15 non-null     int64
#  3   gender      15 non-null     object
#  4   department  15 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 728.0+ bytes

# %%
sns.displot(X['gender'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-7da086f49501> in <cell line: 1>()
# ----> 1 sns.displot(x['gender'])
#
# NameError: name 'x' is not defined

# %%
x=w

# %%
sns.displot(x['gender'])

# %%
sns.barplot(x['sno'])
# Out:
# <Axes: ylabel='sno'>

# %%
sns.barplot(x['name'])
# Out:
# <Axes: ylabel='name'>

# %%
sns.barplot(x['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.barplot(x['department'])
# Out:
# <Axes: ylabel='department'>

# %%
sns.jointplot(x['sno'])

# %%
sns.jointplot(x['name'])

# %%
sns.jointplot(x['age'])

# %%
sns.jointplot(x['department'])

# %%
sns.jointplot(x['gender'])

# %%
sns.jointplot(x['sno'],kind="hex")
#scatter, reg, hex, hist

# %%
sns.jointplot(x['department'],kind="hist")

# %%
sns.jointplot(x['department'],kind="scatter")

# %%
sns.pairplot(x[['name','age','sno']])

# %%
  sns.barplot(x[['age','sno']])
# Out:
# <Axes: >

# %%
sns.stripplot(x[['name','age','sno']])
# Out:
# <Axes: >

# %%
sns.boxplot(x[['name','age','sno']])
# Out:
# <Axes: >

# %%
sns.countplot(x[['name','age','sno']])
# Out:
# <Axes: ylabel='count'>

# %%
sns.pointplot(x[['name','age','sno']])
# Out:
# <Axes: >

# %%
sns.lmplot(x='age',y="sno",data=x)
